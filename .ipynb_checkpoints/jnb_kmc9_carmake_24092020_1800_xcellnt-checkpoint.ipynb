# %%
import pandas as pd
import numpy as np
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
dfcr1 = pd.read_csv('E:/KrishM/PythonPrjs/PyDatasets/carsmakex/cars.csv')

# %%
dfcr1
# Out:
#       mpg   cylinders  cubicinches   hp  weightlbs   time-to-60   year  \
# 0    14.0           8          350  165       4209           12   1972
# 1    31.9           4           89   71       1925           14   1980
# 2    17.0           8          302  140       3449           11   1971
# 3    15.0           8          400  150       3761           10   1971
# 4    30.5           4           98   63       2051           17   1978
# ..    ...         ...          ...  ...        ...          ...    ...
# 256  17.0           8          305  130       3840           15   1980
# 257  36.1           4           91   60       1800           16   1979
# 258  22.0           6          232  112       2835           15   1983
# 259  18.0           6          232  100       3288           16   1972
# 260  22.0           6          250  105       3353           15   1977
#
#         brand
# 0         US.
# 1     Europe.
# 2         US.
# 3         US.
# 4         US.
# ..        ...
# ...

# %%
dfcr2 = dfcr1.copy()

# %%
dfcr2
# Out:
#       mpg   cylinders  cubicinches   hp  weightlbs   time-to-60   year  \
# 0    14.0           8          350  165       4209           12   1972
# 1    31.9           4           89   71       1925           14   1980
# 2    17.0           8          302  140       3449           11   1971
# 3    15.0           8          400  150       3761           10   1971
# 4    30.5           4           98   63       2051           17   1978
# ..    ...         ...          ...  ...        ...          ...    ...
# 256  17.0           8          305  130       3840           15   1980
# 257  36.1           4           91   60       1800           16   1979
# 258  22.0           6          232  112       2835           15   1983
# 259  18.0           6          232  100       3288           16   1972
# 260  22.0           6          250  105       3353           15   1977
#
#         brand
# 0         US.
# 1     Europe.
# 2         US.
# 3         US.
# 4         US.
# ..        ...
# ...

# %%
dfcr2.columns
# Out:
# Index(['mpg', ' cylinders', ' cubicinches', ' hp', ' weightlbs', ' time-to-60',
#        ' year', ' brand'],
#       dtype='object')

# %%
dfcr2.rename(columns = {
    ' cylinders' : 'cylinders',
    ' cubicinches' : 'cubicinches',
    ' hp' : 'hp',
    ' weightlbs' : 'weightlbs',
    ' time-to-60' : 'time60',
    ' year' : 'year',
    ' brand' : 'brand'
},  inplace =True)

# %%
dfcr2
# Out:
#       mpg  cylinders cubicinches   hp weightlbs  time60  year     brand
# 0    14.0          8         350  165      4209      12  1972       US.
# 1    31.9          4          89   71      1925      14  1980   Europe.
# 2    17.0          8         302  140      3449      11  1971       US.
# 3    15.0          8         400  150      3761      10  1971       US.
# 4    30.5          4          98   63      2051      17  1978       US.
# ..    ...        ...         ...  ...       ...     ...   ...       ...
# 256  17.0          8         305  130      3840      15  1980       US.
# 257  36.1          4          91   60      1800      16  1979    Japan.
# 258  22.0          6         232  112      2835      15  1983       US.
# 259  18.0          6         232  100      3288      16  1972       US.
# 260  22.0          6         250  105      3353      15  1977       US.
#
# [261 rows x 8 columns]

# %%
dfcr1.columns
# Out:
# Index(['mpg', 'cylinders', 'cubicinches', 'hp', 'weightlbs', 'time60', 'year',
#        'brand'],
#       dtype='object')

# %%
dfcr2
# Out:
#       mpg  cylinders cubicinches   hp weightlbs  time60  year     brand
# 0    14.0          8         350  165      4209      12  1972       US.
# 1    31.9          4          89   71      1925      14  1980   Europe.
# 2    17.0          8         302  140      3449      11  1971       US.
# 3    15.0          8         400  150      3761      10  1971       US.
# 4    30.5          4          98   63      2051      17  1978       US.
# ..    ...        ...         ...  ...       ...     ...   ...       ...
# 256  17.0          8         305  130      3840      15  1980       US.
# 257  36.1          4          91   60      1800      16  1979    Japan.
# 258  22.0          6         232  112      2835      15  1983       US.
# 259  18.0          6         232  100      3288      16  1972       US.
# 260  22.0          6         250  105      3353      15  1977       US.
#
# [261 rows x 8 columns]

# %%
from sklearn.preprocessing import LabelEncoder

# %%
dfcr2['brand'] = LabelEncoder().fit_transform(dfcr2['brand'])

# %%
dfcr2
# Out:
#       mpg  cylinders cubicinches   hp weightlbs  time60  year  brand
# 0    14.0          8         350  165      4209      12  1972      2
# 1    31.9          4          89   71      1925      14  1980      0
# 2    17.0          8         302  140      3449      11  1971      2
# 3    15.0          8         400  150      3761      10  1971      2
# 4    30.5          4          98   63      2051      17  1978      2
# ..    ...        ...         ...  ...       ...     ...   ...    ...
# 256  17.0          8         305  130      3840      15  1980      2
# 257  36.1          4          91   60      1800      16  1979      1
# 258  22.0          6         232  112      2835      15  1983      2
# 259  18.0          6         232  100      3288      16  1972      2
# 260  22.0          6         250  105      3353      15  1977      2
#
# [261 rows x 8 columns]

# %%
dfcr2.columns
# Out:
# Index(['mpg', 'cylinders', 'cubicinches', 'hp', 'weightlbs', 'time60', 'year',
#        'brand'],
#       dtype='object')

# %%
dfcr2
# Out:
#       mpg  cylinders cubicinches   hp weightlbs  time60  year  brand
# 0    14.0          8         350  165      4209      12  1972      2
# 1    31.9          4          89   71      1925      14  1980      0
# 2    17.0          8         302  140      3449      11  1971      2
# 3    15.0          8         400  150      3761      10  1971      2
# 4    30.5          4          98   63      2051      17  1978      2
# ..    ...        ...         ...  ...       ...     ...   ...    ...
# 256  17.0          8         305  130      3840      15  1980      2
# 257  36.1          4          91   60      1800      16  1979      1
# 258  22.0          6         232  112      2835      15  1983      2
# 259  18.0          6         232  100      3288      16  1972      2
# 260  22.0          6         250  105      3353      15  1977      2
#
# [261 rows x 8 columns]

# %%
dfcr2[dfcr2['cubicinches'] == ' ']
# Out:
#       mpg  cylinders cubicinches   hp weightlbs  time60  year  brand
# 40   16.0          6              105      3897      19  1976      2
# 180  19.8          6               85      2990      18  1980      2

# %%
dfcr2.drop([40, 180], axis = 0, inplace=True)

# %%
dfcr2
# Out:
#       mpg  cylinders cubicinches   hp weightlbs  time60  year  brand
# 0    14.0          8         350  165      4209      12  1972      2
# 1    31.9          4          89   71      1925      14  1980      0
# 2    17.0          8         302  140      3449      11  1971      2
# 3    15.0          8         400  150      3761      10  1971      2
# 4    30.5          4          98   63      2051      17  1978      2
# ..    ...        ...         ...  ...       ...     ...   ...    ...
# 256  17.0          8         305  130      3840      15  1980      2
# 257  36.1          4          91   60      1800      16  1979      1
# 258  22.0          6         232  112      2835      15  1983      2
# 259  18.0          6         232  100      3288      16  1972      2
# 260  22.0          6         250  105      3353      15  1977      2
#
# [259 rows x 8 columns]

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
mmsn1 = MinMaxScaler()

# %%
dfcr2.drop([14, 33, 172], axis=0, inplace=True)

# %%
dfcr2['newweightlbs'] = pd.to_numeric(dfcr2['weightlbs'])

# %%
dfcr2.dtypes
# Out:
# mpg             float64
# cylinders         int64
# cubicinches      object
# hp                int64
# weightlbs        object
# time60            int64
# year              int64
# brand             int32
# newcubic          int64
# newweightlbs      int64
# dtype: object

# %%
dfcr2.drop(columns = ['cubicinches', 'weightlbs'], inplace=True)

# %%
dfcr2
# Out:
#       mpg  cylinders   hp  time60  year  brand  newcubic  newweightlbs
# 0    14.0          8  165      12  1972      2       350          4209
# 1    31.9          4   71      14  1980      0        89          1925
# 2    17.0          8  140      11  1971      2       302          3449
# 3    15.0          8  150      10  1971      2       400          3761
# 4    30.5          4   63      17  1978      2        98          2051
# ..    ...        ...  ...     ...   ...    ...       ...           ...
# 256  17.0          8  130      15  1980      2       305          3840
# 257  36.1          4   60      16  1979      1        91          1800
# 258  22.0          6  112      15  1983      2       232          2835
# 259  18.0          6  100      16  1972      2       232          3288
# 260  22.0          6  105      15  1977      2       250          3353
#
# [256 rows x 8 columns]

# %%
dfcr2.columns
# Out:
# Index(['mpg', 'cylinders', 'hp', 'time60', 'year', 'brand', 'newcubic',
#        'newweightlbs'],
#       dtype='object')

# %%
dfcr2.dtypes
# Out:
# mpg             float64
# cylinders         int64
# hp                int64
# time60            int64
# year              int64
# brand             int32
# newcubic          int64
# newweightlbs      int64
# dtype: object

# %%
dfcr2
# Out:
#       mpg  cylinders   hp  time60  year  brand  newcubic  newweightlbs
# 0    14.0          8  165      12  1972      2       350          4209
# 1    31.9          4   71      14  1980      0        89          1925
# 2    17.0          8  140      11  1971      2       302          3449
# 3    15.0          8  150      10  1971      2       400          3761
# 4    30.5          4   63      17  1978      2        98          2051
# ..    ...        ...  ...     ...   ...    ...       ...           ...
# 256  17.0          8  130      15  1980      2       305          3840
# 257  36.1          4   60      16  1979      1        91          1800
# 258  22.0          6  112      15  1983      2       232          2835
# 259  18.0          6  100      16  1972      2       232          3288
# 260  22.0          6  105      15  1977      2       250          3353
#
# [256 rows x 8 columns]

# %%
mmsc2 = MinMaxScaler()

# %%
dfcr2['newweightlbs'] = mmsc2.fit_transform(dfcr2[['newweightlbs']])

# %%
dfcr2
# Out:
#           mpg  cylinders        hp    time60  year  brand  newcubic  \
# 0    0.109290        1.0  0.646739  0.235294  1972      2  0.727273
# 1    0.598361        0.2  0.135870  0.352941  1980      0  0.049351
# 2    0.191257        1.0  0.510870  0.176471  1971      2  0.602597
# 3    0.136612        1.0  0.565217  0.117647  1971      2  0.857143
# 4    0.560109        0.2  0.092391  0.529412  1978      2  0.072727
# ..        ...        ...       ...       ...   ...    ...       ...
# 256  0.191257        1.0  0.456522  0.411765  1980      2  0.610390
# 257  0.713115        0.2  0.076087  0.470588  1979      1  0.054545
# 258  0.327869        0.6  0.358696  0.411765  1983      2  0.420779
# 259  0.218579        0.6  0.293478  0.470588  1972      2  0.420779
# 260  0.327869        0.6  0.320652  0.411765  1977      2  0.467532
#
#      newweightlbs
# 0        0.767139
# 1        0.092199
# 2        0.542553
# 3        0.634752
# 4        0.129433
# ..            ...
# ...

# %%
kmc2 = KMeans(n_clusters = 7)

# %%
kmc2
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#        n_clusters=7, n_init=10, n_jobs=None, precompute_distances='auto',
#        random_state=None, tol=0.0001, verbose=0)

# %%
vals_pred = kmc2.fit_predict(dfcr2)

# %%
vals_pred
# Out:
# array([2, 3, 2, 2, 3, 3, 4, 2, 3, 1, 1, 1, 4, 4, 3, 3, 2, 6, 6, 1, 5, 0,
#        3, 1, 5, 6, 0, 0, 1, 2, 4, 6, 3, 1, 6, 3, 3, 3, 4, 0, 3, 2, 1, 0,
#        4, 5, 1, 4, 3, 2, 6, 0, 4, 5, 3, 5, 4, 4, 4, 1, 1, 4, 3, 6, 1, 5,
#        3, 4, 1, 6, 5, 5, 1, 0, 3, 6, 1, 3, 4, 3, 5, 5, 6, 2, 1, 4, 1, 3,
#        3, 4, 2, 0, 0, 4, 2, 3, 4, 4, 4, 4, 3, 1, 1, 1, 6, 5, 2, 4, 6, 3,
#        5, 3, 0, 3, 0, 1, 2, 5, 5, 0, 3, 6, 0, 4, 3, 6, 3, 5, 1, 4, 4, 0,
#        0, 2, 0, 5, 6, 3, 5, 1, 1, 3, 5, 3, 1, 2, 3, 1, 3, 2, 0, 5, 2, 4,
#        3, 2, 3, 1, 3, 0, 4, 6, 3, 2, 1, 4, 1, 1, 3, 1, 4, 6, 4, 4, 3, 3,
#        1, 0, 2, 1, 3, 0, 0, 4, 4, 1, 3, 4, 4, 4, 1, 1, 3, 5, 3, 5, 0, 3,
#        3, 4, 2, 1, 4, 4, 1, 3, 3, 1, 6, 0, 1, 1, 0, 3, 3, 0, 3, 4, 5, 4,
#        5, 2, 5, 2, 1, 2, 1, 0, 0, 5, 1, 2, 3, 1, 2, 0, 4, 3, 6, 2, 4, 3,
#        1, 5, 1, 1, 6, 1, 4, 1, 2, 3, 3, 1, 2, 0])

# %%
kmc2.cluster_centers_
# Out:
# array([[2.23761070e-01, 7.10344828e-01, 3.81371814e-01, 4.46247465e-01,
#         1.97655172e+03, 2.00000000e+00, 4.96372593e-01, 5.79634385e-01],
#        [6.09236044e-01, 2.66666667e-01, 1.78282182e-01, 5.32871972e-01,
#         1.98198039e+03, 1.37254902e+00, 1.46167558e-01, 2.48684698e-01],
#        [1.95967590e-01, 7.79310345e-01, 5.22113943e-01, 2.81947262e-01,
#         1.97134483e+03, 1.93103448e+00, 5.89879086e-01, 5.31181218e-01],
#        [3.80931838e-01, 5.54385965e-01, 3.22463768e-01, 4.47884417e-01,
#         1.97907018e+03, 1.50877193e+00, 3.42128047e-01, 4.18139024e-01],
#        [1.63934426e-01, 7.77272727e-01, 5.03952569e-01, 3.64973262e-01,
#         1.97393182e+03, 1.90909091e+00, 5.61688312e-01, 6.16974264e-01],
#        [4.45039933e-01, 2.30769231e-01, 1.98160535e-01, 4.52488688e-01,
#         1.97630769e+03, 3.07692308e-01, 9.73026973e-02, 2.18164666e-01],
#        [4.24863388e-01, 2.00000000e-01, 1.79619565e-01, 5.61764706e-01,
# ...

# %%
kmc2.cluster_centers_[3]
# Out:
# array([3.80931838e-01, 5.54385965e-01, 3.22463768e-01, 4.47884417e-01,
#        1.97907018e+03, 1.50877193e+00, 3.42128047e-01, 4.18139024e-01])

# %%
kmc2.inertia_
# Out:
# 265.63012687997406

# %%
krng = range(1, 25)
sse = []
for k in krng:
    km = KMeans(n_clusters = k)
    km.fit(dfcr2)
    sse.append(km.inertia_)

# %%
krng
# Out:
# range(1, 25)

# %%
sse
# Out:
# [3627.08770050265,
#  1141.6594776079583,
#  623.0937549404525,
#  472.37276011796695,
#  357.58355653019464,
#  305.97561891846243,
#  262.3645919728611,
#  222.45795384192598,
#  195.23048244313583,
#  172.06729077622762,
#  151.98846947198268,
#  138.48660761895962,
#  127.04067673648802,
#  115.67698450734736,
#  113.52498116091625,
#  105.78801390821954,
#  100.7762155947789,
#  89.95644040674323,
#  87.99181533639072,
#  83.53391629282173,
#  78.64344876814032,
#  75.23177275135973,
#  71.68656181731728,
#  65.33535372245139]

# %%
plt.plot(krng, sse)
