# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn.datasets import make_blobs

# %%
dsbb1 = make_blobs(n_samples = 500, centers = 4, cluster_std = 15)

# %%
dsbb1
# Out:
# (array([[ 7.39738187e+00,  1.93005562e+01],
#         [-2.28135592e+01,  2.00635908e+01],
#         [-3.26711543e+01,  3.28470866e+00],
#         [-1.15619494e+01,  2.72277534e+00],
#         [-2.74898856e+01,  2.17942359e+00],
#         [ 2.05034370e+01,  3.36361860e+00],
#         [ 8.06435433e+00,  1.81986383e+01],
#         [ 5.15574034e+00,  1.10983841e+00],
#         [-6.87632970e+00,  5.29707651e-01],
#         [-3.01337550e+01, -2.18290015e+00],
#         [-2.02118580e+01, -2.11129317e+00],
#         [-9.75840970e-01, -6.10326998e+00],
#         [-2.08295092e+00,  2.09573662e+01],
#         [-2.13848794e+01,  1.20076657e+01],
#         [-9.13447162e+00,  1.54875668e+01],
#         [-3.05870981e-01,  7.89463808e-01],
#         [-2.09005886e+01,  1.04681713e+01],
#         [-2.66350375e+01,  1.90381019e+01],
#         [-1.00512095e+01, -9.42853389e+00],
#         [ 5.33384031e+00,  9.41277094e+00],
#         [-8.86913180e-01,  3.64493535e+01],
# ...

# %%
dfbb1 = pd.DataFrame(dsbb1[0], dsbb1[1], dsbb1)

# %%
dfbb1
# Out:
#             0          1
# 3    7.397382  19.300556
# 0  -22.813559  20.063591
# 1  -32.671154   3.284709
# 3  -11.561949   2.722775
# 2  -27.489886   2.179424
# ..        ...        ...
# 3  -46.152614  13.979779
# 3   -8.515524 -14.439583
# 1   -9.130785   4.277313
# 3  -19.964095  28.086339
# 1  -19.138412   5.620913
#
# [500 rows x 2 columns]
